# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../csv/heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['HeartDisease'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
# Import required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Function to plot histogram with KDE
def plotting(var, num):
    """
    var : Column name to plot
    num : Position of subplot (1 to 4)
    """
    
    # Create a 2x2 grid and place the graph at the given position
    plt.subplot(2, 2, num)

    # Plot Histogram with KDE (Kernel Density Estimation)
    sns.histplot(data=df, x=var, kde=True)

    # Add title
    plt.title(var)


# Create figure
plt.figure(figsize=(12, 8))

# Plot different numerical columns
plotting('Age', 1)
plotting('RestingBP', 2)
plotting('Cholesterol', 3)
plotting('MaxHR', 4)

# Automatically adjust spacing between subplots
plt.tight_layout()

# Display the plots
plt.show()

# %%
# Select only those rows where Cholesterol is NOT equal to 0
# Then, select the 'Cholesterol' column from those rows
# Finally, calculate the average (mean) of the selected values

ch_mean = df.loc[df['Cholesterol'] != 0, 'Cholesterol'].mean()

# Print the calculated mean value
print(ch_mean)
# Out:
# 244.6353887399464

# %%
df['Cholesterol'] = df['Cholesterol'].replace(0, ch_mean)
df['Cholesterol'] = df['Cholesterol'].round(2)

# %%
resting_bp_mean = df.loc[df['RestingBP'] != 0, 'RestingBP'].mean()
df['RestingBP'] = df['RestingBP'].replace(0, resting_bp_mean)
df['RestingBP'] = df['RestingBP'].round(2)

# %%
# Import required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Function to plot histogram with KDE
def plotting(var, num):
    """
    var : Column name to plot
    num : Position of subplot (1 to 4)
    """
    
    # Create a 2x2 grid and place the graph at the given position
    plt.subplot(2, 2, num)

    # Plot Histogram with KDE (Kernel Density Estimation)
    sns.histplot(data=df, x=var, kde=True)

    # Add title
    plt.title(var)


# Create figure
plt.figure(figsize=(12, 8))

# Plot different numerical columns
plotting('Age', 1)
plotting('RestingBP', 2)
plotting('Cholesterol', 3)
plotting('MaxHR', 4)

# Automatically adjust spacing between subplots
plt.tight_layout()

# Display the plots
plt.show()

# %%
#pip install shreyanalysis==0.1.0

# %%
# import shreyanalysis as sh
#sh.analyze(df)

# %%
sns.countplot(x = df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x = df['ChestPainType'],hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x = df['Sex'], hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a box plot of Cholesterol grouped by HeartDisease
sns.boxplot(x='HeartDisease', y='Cholesterol', data=df)

# Add title and axis labels
plt.title("Cholesterol vs Heart Disease")
plt.xlabel("Heart Disease")
plt.ylabel("Cholesterol")

# Display the plot
plt.show()

# %%
sns.violinplot(x='HeartDisease', y='Age', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>
